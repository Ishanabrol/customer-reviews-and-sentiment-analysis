# %% [markdown]
# # Customer Purchase Behaviour & Sentiment Analysis
#
# ## Project Objective
# The objective of this project is to analyse customer purchase behaviour and review sentiment to understand customer satisfaction levels, product perception, and engagement trends. This analysis will help identify patterns in how customers interact with products and how their feedback reflects their overall experience.
#
# ---
#
# ## What This Project Helps Us Discover
# - Which products customers are most satisfied or dissatisfied with
# - Overall customer sentiment trends over time
# - Customer behaviour patterns reflected through reviews
# - Insights that can support business decision-making and service improvement
#
# ---
#
# ## Project Flow
# 1. Data cleaning in Python to prepare and process the raw review data
# 2. SQL analysis in PostgreSQL to extract business insights from the dataset
# 3. Data visualisation in Python to present key findation interpretation
# r interpretation   interpretation

# %%
import sys

# install required packages in the SAME environment Jupyter is using
# !{sys.executable} -m pip install textblob nltk pandas matplotlib seaborn
# Out:
# Collecting textblob
#   Downloading textblob-0.19.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: nltk in c:\users\ishaa\anaconda3\lib\site-packages (3.8.1)
# Requirement already satisfied: pandas in c:\users\ishaa\anaconda3\lib\site-packages (2.1.4)
# Requirement already satisfied: matplotlib in c:\users\ishaa\anaconda3\lib\site-packages (3.8.0)
# Requirement already satisfied: seaborn in c:\users\ishaa\anaconda3\lib\site-packages (0.12.2)
# Collecting nltk
#   Downloading nltk-3.9.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: click in c:\users\ishaa\anaconda3\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\ishaa\anaconda3\lib\site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\ishaa\anaconda3\lib\site-packages (from nltk) (2023.10.3)
# Requirement already satisfied: tqdm in c:\users\ishaa\anaconda3\lib\site-packages (from nltk) (4.65.0)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\ishaa\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ishaa\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ishaa\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\ishaa\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ishaa\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ishaa\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ishaa\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ishaa\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ishaa\anaconda3\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ishaa\anaconda3\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ishaa\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: six>=1.5 in c:\users\ishaa\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: colorama in c:\users\ishaa\anaconda3\lib\site-packages (from click->nltk) (0.4.6)
# Downloading textblob-0.19.0-py3-none-any.whl (624 kB)
#    ---------------------------------------- 0.0/624.3 kB ? eta -:--:--
#     --------------------------------------- 10.2/624.3 kB ? eta -:--:--
#    --- ------------------------------------ 61.4/624.3 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------  614.4/624.3 kB 6.5 MB/s eta 0:00:01
#    ---------------------------------------- 624.3/624.3 kB 5.6 MB/s eta 0:00:00
# Downloading nltk-3.9.2-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    -------------------------------------- - 1.5/1.5 MB 30.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 24.2 MB/s eta 0:00:00
# Installing collected packages: nltk, textblob
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.8.1
#     Uninstalling nltk-3.8.1:
#       Successfully uninstalled nltk-3.8.1
# Successfully installed nltk-3.9.2 textblob-0.19.0

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ishaa\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\ishaa\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# True

# %%
from textblob import TextBlob
TextBlob("The product is amazing!").sentiment  # to check if code works
# Out:
# Sentiment(polarity=0.7500000000000001, subjectivity=0.9)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from textblob import TextBlob   # for sentiment analysis
import re   # for cleaning text (regular expressions module)
import nltk  # Natural Language Toolkit to provide tool 'stopwords'
nltk.download('stopwords')  # Downloads English stopwords 
from nltk.corpus import stopwords   # lets us remove common filter words

sns.set()  # makes visualization looks better
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ishaa\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = pd.read_csv("customer_reviews_data.csv")

# %%
df.head()
# Out:
#    ReviewID  CustomerID  ProductID  \
# 0         1         486        267
# 1         2         810        246
# 2         3         855        291
# 3         4         524        235
# 4         5         238        220
#
#                                           ReviewText  ReviewDate
# 0  So impressed by the quality. This product trul...   5/12/2024
# 1  I'm very happy with the performance. It does e...    3/7/2024
# 2  I regret buying this. The quality is terrible ...  11/15/2023
# 3  It serves its purpose, but it's not anything e...   5/27/2024
# 4  Very high-quality product. I would buy it agai...   9/10/2023

# %%
df.shape
# Out:
# (1000, 5)

# %%
df.describe(include='all')
# Out:
#            ReviewID   CustomerID    ProductID  \
# count   1000.000000  1000.000000  1000.000000
# unique          NaN          NaN          NaN
# top             NaN          NaN          NaN
# freq            NaN          NaN          NaN
# mean     500.500000   554.596000   248.977000
# min        1.000000   100.000000   200.000000
# 25%      250.750000   343.500000   223.000000
# 50%      500.500000   563.500000   249.000000
# 75%      750.250000   744.750000   275.000000
# max     1000.000000   999.000000   299.000000
# std      288.819436   246.709076    29.317674
#
#                                                ReviewText  \
# count                                                1000
# unique                                                189
# top     Very high-quality product. I would buy it agai...
# freq                                                   15
# mean                                                  NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
# std                                                   NaN
#
#                         ReviewDate
# count                         1000
# unique                         NaN
# top                            NaN
# freq                           NaN
# mean    2023-12-24 17:11:02.400000
# min            2023-06-26 00:00:00
# 25%            2023-09-29 00:00:00
# 50%            2023-12-25 00:00:00
# 75%            2024-03-27 00:00:00
# max            2024-06-25 00:00:00
# std                            NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ReviewID    1000 non-null   int64
#  1   CustomerID  1000 non-null   int64
#  2   ProductID   1000 non-null   int64
#  3   ReviewText  1000 non-null   object
#  4   ReviewDate  1000 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 39.2+ KB

# %%
df.isnull().sum()
# Out:
# ReviewID      0
# CustomerID    0
# ProductID     0
# ReviewText    0
# ReviewDate    0
# dtype: int64

# %%
(df['ReviewText'].str.strip() == "").sum() # to check null string valus
# Out:
# 0

# %%
# to check if ReviewDate column is datetime type
# the datetime type columns hepls in sorting by date, extract year/month/date
# or to analyze trends over time
df.dtypes
# Out:
# ReviewID       int64
# CustomerID     int64
# ProductID      int64
# ReviewText    object
# ReviewDate    object
# dtype: object

# %%
df['ReviewDate'] = pd.to_datetime(df['ReviewDate'])

# %%
df.dtypes
# Out:
# ReviewID               int64
# CustomerID             int64
# ProductID              int64
# ReviewText            object
# ReviewDate    datetime64[ns]
# dtype: object

# %%
# to check if duplicate reiews exists
df['ReviewID'].duplicated().sum()
# Out:
# 0

# %%
# install contraction to covert "don't" to "do not"
import sys
# !{sys.executable} -m pip install contractions
# Out:
# Collecting contractions
#   Downloading contractions-0.1.73-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting textsearch>=0.0.21 (from contractions)
#   Downloading textsearch-0.0.24-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting anyascii (from textsearch>=0.0.21->contractions)
#   Downloading anyascii-0.3.3-py3-none-any.whl.metadata (1.6 kB)
# Collecting pyahocorasick (from textsearch>=0.0.21->contractions)
#   Downloading pyahocorasick-2.3.0-cp311-cp311-win_amd64.whl.metadata (14 kB)
# Downloading contractions-0.1.73-py2.py3-none-any.whl (8.7 kB)
# Downloading textsearch-0.0.24-py2.py3-none-any.whl (7.6 kB)
# Downloading anyascii-0.3.3-py3-none-any.whl (345 kB)
#    ---------------------------------------- 0.0/345.1 kB ? eta -:--:--
#    ------------------- ------------------- 174.1/345.1 kB 10.9 MB/s eta 0:00:01
#    ---------------------------------------- 345.1/345.1 kB 5.4 MB/s eta 0:00:00
# Downloading pyahocorasick-2.3.0-cp311-cp311-win_amd64.whl (35 kB)
# Installing collected packages: pyahocorasick, anyascii, textsearch, contractions
# Successfully installed anyascii-0.3.3 contractions-0.1.73 pyahocorasick-2.3.0 textsearch-0.0.24

# %%
# Text Cleaning

import re
import contractions
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))

negation_words = {"not", "no", "don't", "doesn't", "didn't", "isn't",
                  "wasn't", "weren't", "won't", "can't", "couldn't", 
                  "shouldn't", "haven't", "hasn't", "hadn't"}

for w in negation_words:
    stop_words.discard(w)

# %%
def clean_text(text):

    # ensure string in lowercase
    text = str(text).lower()
    # expand contractions
    text = contractions.fix(text)
    # remove exerything except letters + spaces
    text = re.sub(r'[^a-z\s]', ' ', text)
    # remove extra spaces
    text = re.sub(r'\s+', ' ', text).strip()
    # remove stopwords EXCEPT negations
    text = " ".join(
    word for word in text.split()
    if word not in stop_words
    ) 
    return text

# Apply to the dataset
df['CleanReview'] = df['ReviewText'].apply(clean_text)

# %%
df.dtypes
# Out:
# ReviewID                int64
# CustomerID              int64
# ProductID               int64
# ReviewText             object
# ReviewDate     datetime64[ns]
# CleanReview            object
# dtype: object

# %%
# creating columns for various functions
# to count words in cleaned review
df['ReviewLength'] = df['CleanReview'].apply(lambda x: len(x.split()))
df['Year'] = df['ReviewDate'].dt.year  # To extract year
df['Month'] = df['ReviewDate'].dt.month  # to extract month
df['Weekday'] = df ['ReviewDate'].dt.day_name() # to extract weekday

df.dtypes
# Out:
# ReviewID                 int64
# CustomerID               int64
# ProductID                int64
# ReviewText              object
# ReviewDate      datetime64[ns]
# CleanReview             object
# ReviewLength             int64
# Year                     int32
# Month                    int32
# Weekday                 object
# dtype: object

# %%
# Create sentiment score
from textblob import TextBlob   # library for sentiment

def sentiment_score(text):
    return TextBlob(text).sentiment.polarity  # provide sentiment score

df['SentimentScore'] = df['CleanReview'].apply(sentiment_score)

# %%
# Convert sentiment score into sentiment label
def label_sentiment(score):
    if score > 0.1:
        return "Positive"
    elif score < -0.1:
        return "Negative"
    else:
        return "Neutral"

df['SentimentLabel'] = df['SentimentScore'].apply(label_sentiment)

# %%
df.head()
# Out:
#    ReviewID  CustomerID  ProductID  \
# 0         1         486        267
# 1         2         810        246
# 2         3         855        291
# 3         4         524        235
# 4         5         238        220
#
#                                           ReviewText ReviewDate  \
# 0  So impressed by the quality. This product trul... 2024-05-12
# 1  I'm very happy with the performance. It does e... 2024-03-07
# 2  I regret buying this. The quality is terrible ... 2023-11-15
# 3  It serves its purpose, but it's not anything e... 2024-05-27
# 4  Very high-quality product. I would buy it agai... 2023-09-10
#
#                                          CleanReview  ReviewLength  Year  \
# 0           impressed quality product truly delivers             5  2024
# 1                     happy performance exactly need             4  2024
# 2  regret buying quality terrible stopped working...             8  2023
# 3          serves purpose not anything extraordinary             5  2024
# 4  high quality product would buy without hesitation             7  2023
#
#    Month    Weekday  SentimentScore SentimentLabel
# 0      5     Sunday        1.000000       Positive
# 1      3   Thursday        0.525000       Positive
# 2     11  Wednesday       -1.000000       Negative
# 3      5     Monday        0.333333       Positive
# 4      9     Sunday        0.160000       Positive

# %%
# export cleaned dataset to CSV file
df.to_csv("cleaned_customer_reviews_sentiment.csv", index = False)
